# %% [markdown]
# We first generate medically structured seed data using clinical rules,
# then use generative models (SynthCity) to scale it while preserving distributions.

# %%
import numpy as np
import pandas as pd

# %%
N = 2000  # seed dataset size

risk_levels = np.random.choice(
    [0, 1, 2],
    size=N,
    p=[0.60, 0.25, 0.15]
)

df = pd.DataFrame({
    "risk_level": risk_levels
})

df["risk_level"].value_counts(normalize=True)
# Out:
# risk_level
# 0    0.5955
# 1    0.2655
# 2    0.1390
# Name: proportion, dtype: float64

# %%
import random

def bernoulli(p):
    return 1 if random.random() < p else 0

maternal_rows = []

for r in df["risk_level"]:
    if r == 0:   # LOW
        prom_p = bernoulli(0.15)
        fever_p = bernoulli(0.08)
        row = {
            "prom_present": prom_p,
            "chorioamnionitis": bernoulli(0.05),
            "foul_smelling_liquor": bernoulli(0.05),
            "prolonged_labor": bernoulli(0.10),
            "unbooked_pregnancy": bernoulli(0.15),
            "maternal_uti_sti": bernoulli(0.08),
            "meconium_stained_liquor": bernoulli(0.10),
            "cotwin_iud": bernoulli(0.02),
            "pv_examinations_count": random.randint(1,2)
        }
        row["prom_duration_hours"] = random.uniform(2,10) if prom_p else 0
        row["maternal_fever_celsius"] = random.uniform(37.5,38.2) if fever_p else random.uniform(36.5,37.4)

    elif r == 1: # MODERATE
        prom_p = bernoulli(0.40)
        fever_p = bernoulli(0.30)
        row = {
            "prom_present": prom_p,
            "chorioamnionitis": bernoulli(0.25),
            "foul_smelling_liquor": bernoulli(0.20),
            "prolonged_labor": bernoulli(0.35),
            "unbooked_pregnancy": bernoulli(0.40),
            "maternal_uti_sti": bernoulli(0.25),
            "meconium_stained_liquor": bernoulli(0.30),
            "cotwin_iud": bernoulli(0.08),
            "pv_examinations_count": random.randint(2,4)
        }
        row["prom_duration_hours"] = random.uniform(6,18) if prom_p else 0
        row["maternal_fever_celsius"] = random.uniform(38.0,38.8) if fever_p else random.uniform(36.5,37.4)

    else:       # HIGH
        prom_p = bernoulli(0.75)
        fever_p = bernoulli(0.65)
        row = {
            "prom_present": prom_p,
            "chorioamnionitis": bernoulli(0.60),
            "foul_smelling_liquor": bernoulli(0.55),
            "prolonged_labor": bernoulli(0.65),
            "unbooked_pregnancy": bernoulli(0.70),
            "maternal_uti_sti": bernoulli(0.55),
            "meconium_stained_liquor": bernoulli(0.60),
            "cotwin_iud": bernoulli(0.15),
            "pv_examinations_count": random.randint(3,6)
        }
        row["prom_duration_hours"] = random.uniform(12,36) if prom_p else 0
        row["maternal_fever_celsius"] = random.uniform(38.5,40.0) if fever_p else random.uniform(36.5,37.4)

    maternal_rows.append(row)

maternal_df = pd.DataFrame(maternal_rows)
df = pd.concat([df, maternal_df], axis=1)

df.head()
# Out:
#    risk_level  prom_present  chorioamnionitis  foul_smelling_liquor  \
# 0           1             0                 0                     0
# 1           2             0                 1                     0
# 2           1             1                 0                     0
# 3           0             0                 0                     0
# 4           2             1                 0                     0
#
#    prolonged_labor  unbooked_pregnancy  maternal_uti_sti  \
# 0                1                   0                 1
# 1                1                   0                 0
# 2                0                   1                 1
# 3                0                   0                 0
# 4                1                   1                 1
#
#    meconium_stained_liquor  cotwin_iud  pv_examinations_count  \
# 0                        0           0                      3
# 1                        0           0                      4
# 2                        0           0                      4
# 3                        0           0                      1
# 4                        1           0                      6
#
#    prom_duration_hours  maternal_fever_celsius
# 0             0.000000               36.555410
# 1             0.000000               36.687441
# 2            11.531519               37.370933
# 3             0.000000               36.984520
# 4            25.514795               39.098882

# %%
df.groupby("risk_level")["prom_present"].mean()
df.groupby("risk_level")["maternal_fever_celsius"].mean()
# Out:
# risk_level
# 0    37.026882
# 1    37.350209
# 2    38.383578
# Name: maternal_fever_celsius, dtype: float64

# %%
def categorical_choice(probs):
    return np.random.choice(len(probs), p=probs)

neonatal_rows = []

for i, row in df.iterrows():
    r = row["risk_level"]

    maternal_push = 0
    if row["maternal_fever_celsius"] > 38 or row["chorioamnionitis"] == 1:
        maternal_push = 0.3

    # ----- Temperature -----
    if r == 0:
        temp = random.uniform(36.5, 37.5)
    elif r == 1:
        temp = random.uniform(36.0, 38.0)
    else:
        temp = random.uniform(35.5, 39.5)

    temp += maternal_push * random.uniform(0.2, 0.6)
    temp = round(temp, 2)

    # ----- Feeding -----
    if r == 0:
        feeding = categorical_choice([0.80, 0.15, 0.05])
    elif r == 1:
        feeding = categorical_choice([0.45, 0.35, 0.20])
    else:
        feeding = categorical_choice([0.20, 0.40, 0.40])

    # ----- Activity -----
    if r == 0:
        activity = categorical_choice([0.80, 0.15, 0.05])
    elif r == 1:
        activity = categorical_choice([0.40, 0.35, 0.25])
    else:
        activity = categorical_choice([0.15, 0.35, 0.50])

    # ----- Respiratory Distress -----
    if r == 0:
        resp = bernoulli(0.08)
    elif r == 1:
        resp = bernoulli(0.35)
    else:
        resp = bernoulli(0.75)

    # ----- Apnea -----
    if r == 0:
        apnea = bernoulli(0.03)
    elif r == 1:
        apnea = bernoulli(0.20)
    else:
        apnea = bernoulli(0.55)

    # ----- Shock -----
    if r == 0:
        shock = bernoulli(0.02)
    elif r == 1:
        shock = bernoulli(0.15)
    else:
        shock = bernoulli(0.45)

    # ----- Heart Rate -----
    if r == 0:
        hr = random.randint(120,160)
    elif r == 1:
        hr = random.randint(110,180)
    else:
        hr = random.randint(90,210)

    if shock or resp:
        hr += random.randint(-15, 20)

    neonatal_rows.append({
        "temperature_celsius": temp,
        "feeding_status": feeding,
        "activity_level": activity,
        "respiratory_distress": resp,
        "heart_rate_bpm": hr,
        "apnea_present": apnea,
        "shock_present": shock
    })

neonatal_df = pd.DataFrame(neonatal_rows)
df = pd.concat([df, neonatal_df], axis=1)

df.head()
# Out:
#    risk_level  prom_present  chorioamnionitis  foul_smelling_liquor  \
# 0           1             0                 0                     0
# 1           2             0                 1                     0
# 2           1             1                 0                     0
# 3           0             0                 0                     0
# 4           2             1                 0                     0
#
#    prolonged_labor  unbooked_pregnancy  maternal_uti_sti  \
# 0                1                   0                 1
# 1                1                   0                 0
# 2                0                   1                 1
# 3                0                   0                 0
# 4                1                   1                 1
#
#    meconium_stained_liquor  cotwin_iud  pv_examinations_count  \
# 0                        0           0                      3
# 1                        0           0                      4
# 2                        0           0                      4
# 3                        0           0                      1
# 4                        1           0                      6
#
#    prom_duration_hours  maternal_fever_celsius  temperature_celsius  \
# 0             0.000000               36.555410                37.81
# 1             0.000000               36.687441                39.34
# 2            11.531519               37.370933                37.61
# 3             0.000000               36.984520                37.43
# 4            25.514795               39.098882                37.42
#
#    feeding_status  activity_level  respiratory_distress  heart_rate_bpm  \
# 0               1               0                     0             144
# 1               2               2                     1             142
# 2               2               0                     0             148
# 3               0               2                     1             153
# 4               1               2                     1             157
#
#    apnea_present  shock_present
# 0              1              0
# 1              0              1
# 2              0              1
# 3              0              0
# 4              0              1

# %%
df.groupby("risk_level")["respiratory_distress"].mean()
df.groupby("risk_level")["feeding_status"].mean()
df.groupby("risk_level")["temperature_celsius"].mean()
# Out:
# risk_level
# 0    37.018556
# 1    37.048795
# 2    37.682266
# Name: temperature_celsius, dtype: float64

# %%
hss_rows = []

for i, row in df.iterrows():

    severity = row["risk_level"]
    if row["shock_present"] == 1:
        severity += 1
    if row["apnea_present"] == 1:
        severity += 1
    if row["respiratory_distress"] == 1:
        severity += 1

    if severity == 0:
        p = 0.05
    elif severity == 1:
        p = 0.15
    elif severity == 2:
        p = 0.30
    elif severity == 3:
        p = 0.50
    else:
        p = 0.70

    tlc = bernoulli(p)
    anc = bernoulli(p)
    it_ratio = bernoulli(p + 0.05)
    im_ratio = bernoulli(p + 0.05)
    platelet = bernoulli(p + 0.10)
    neut_deg = bernoulli(p)
    nrbc = bernoulli(p)

    hss_score = tlc + anc + it_ratio + im_ratio + platelet + neut_deg + nrbc

    hss_rows.append({
        "hss_tlc_abnormal": tlc,
        "hss_anc_abnormal": anc,
        "hss_it_ratio_high": it_ratio,
        "hss_im_ratio_high": im_ratio,
        "hss_platelet_low": platelet,
        "hss_neutrophil_degeneration": neut_deg,
        "hss_nrbc_elevated": nrbc,
        "hss_score": hss_score
    })

hss_df = pd.DataFrame(hss_rows)
df = pd.concat([df, hss_df], axis=1)

df[["risk_level","hss_score"]].groupby("risk_level").mean()
# Out:
#             hss_score
# risk_level
# 0            0.647355
# 1            2.092279
# 2            4.453237

# %%
def apgar_component(probs):
    return np.random.choice([0,1,2], p=probs)

apgar_rows = []

for i, row in df.iterrows():
    r = row["risk_level"]

    # ---------- Base probabilities (1 min) ----------
    if r == 0:
        base_probs = [0.05, 0.15, 0.80]
    elif r == 1:
        base_probs = [0.20, 0.35, 0.45]
    else:
        base_probs = [0.45, 0.40, 0.15]

    # ---------- Severity penalty ----------
    penalty = 0
    if row["respiratory_distress"] == 1:
        penalty += 0.10
    if row["apnea_present"] == 1:
        penalty += 0.10
    if row["shock_present"] == 1:
        penalty += 0.15

    # Adjust probabilities safely
    p0 = min(base_probs[0] + penalty, 0.70)
    p2 = max(base_probs[2] - penalty, 0.05)
    p1 = 1 - (p0 + p2)
    probs_1min = [p0, p1, p2]

    # ---------- APGAR 1 min ----------
    a1 = apgar_component(probs_1min)
    p1c = apgar_component(probs_1min)
    g1 = apgar_component(probs_1min)
    ac1 = apgar_component(probs_1min)
    r1 = apgar_component(probs_1min)

    apgar1_total = a1 + p1c + g1 + ac1 + r1

    # ---------- APGAR 5 min (improvement) ----------
    def improve(x):
        if row["shock_present"] == 1:
            return x  # no improvement
        return min(x + np.random.choice([0,1], p=[0.4,0.6]), 2)

    a5 = improve(a1)
    p5c = improve(p1c)
    g5 = improve(g1)
    ac5 = improve(ac1)
    r5 = improve(r1)

    apgar5_total = a5 + p5c + g5 + ac5 + r5

    apgar_rows.append({
        "apgar1_appearance": a1,
        "apgar1_pulse": p1c,
        "apgar1_grimace": g1,
        "apgar1_activity": ac1,
        "apgar1_respiration": r1,
        "apgar1_total": apgar1_total,

        "apgar5_appearance": a5,
        "apgar5_pulse": p5c,
        "apgar5_grimace": g5,
        "apgar5_activity": ac5,
        "apgar5_respiration": r5,
        "apgar5_total": apgar5_total
    })

apgar_df = pd.DataFrame(apgar_rows)
df = pd.concat([df, apgar_df], axis=1)

df.groupby("risk_level")[["apgar1_total","apgar5_total"]].mean()
# Out:
#             apgar1_total  apgar5_total
# risk_level
# 0               8.658270      9.257767
# 1               5.335217      6.785311
# 2               2.187050      3.593525

# %%
baseline_rows = []

for i, row in df.iterrows():
    r = row["risk_level"]

    # ----- Gestational age -----
    if r == 0:
        ga = np.random.choice(["<34", "34–36", "≥37"], p=[0.05,0.15,0.80])
    elif r == 1:
        ga = np.random.choice(["<34", "34–36", "≥37"], p=[0.15,0.30,0.55])
    else:
        ga = np.random.choice(["<34", "34–36", "≥37"], p=[0.35,0.35,0.30])

    # ----- Birth weight -----
    if r == 0:
        bw = np.random.choice(["<1500", "1500–2499", "≥2500"], p=[0.05,0.15,0.80])
    elif r == 1:
        bw = np.random.choice(["<1500", "1500–2499", "≥2500"], p=[0.15,0.35,0.50])
    else:
        bw = np.random.choice(["<1500", "1500–2499", "≥2500"], p=[0.40,0.35,0.25])

    # ----- Resuscitation -----
    apgar1 = row["apgar1_total"]
    if apgar1 >= 7:
        resus = bernoulli(0.05)
    elif apgar1 >= 4:
        resus = bernoulli(0.40)
    else:
        resus = bernoulli(0.80)

    # ----- Sex -----
    sex = np.random.choice(["male", "female"], p=[0.52,0.48])

    baseline_rows.append({
        "gestational_age_category": ga,
        "birth_weight_category": bw,
        "resuscitation_required": resus,
        "neonatal_sex": sex
    })

baseline_df = pd.DataFrame(baseline_rows)
df = pd.concat([df, baseline_df], axis=1)

# %%
mnrs_list = []

for i, d in df.iterrows():
    s = 0

    # ---- A. Antenatal / Peripartum ----

    if d["prom_present"] == 1 and d["prom_duration_hours"] >= 18:
        s += 3
    if d["chorioamnionitis"] == 1:
        s += 3
    if d["maternal_fever_celsius"] >= 38:
        s += 3

    if d["foul_smelling_liquor"] == 1:
        s += 2
    if d["pv_examinations_count"] >= 3:
        s += 2
    if d["meconium_stained_liquor"] == 1:
        s += 2
    if d["prolonged_labor"] == 1:
        s += 2

    if d["unbooked_pregnancy"] == 1:
        s += 1
    if d["maternal_uti_sti"] == 1:
        s += 1
    if d["cotwin_iud"] == 1:
        s += 1

    # ---- B. Neonatal baseline ----

    if d["gestational_age_category"] == "<34":
        s += 3
    elif d["gestational_age_category"] == "34–36":
        s += 2

    if d["birth_weight_category"] == "<1500":
        s += 3
    elif d["birth_weight_category"] == "1500–2499":
        s += 2

    if d["apgar5_total"] < 7:
        s += 3
    elif d["apgar1_total"] < 7:
        s += 2

    if d["resuscitation_required"] == 1:
        s += 3
    if d["neonatal_sex"] == "male":
        s += 1

    # ---- C. Early clinical (0–72h) ----

    if d["temperature_celsius"] < 36 or d["temperature_celsius"] > 38:
        s += 3

    if d["feeding_status"] >= 1 or d["activity_level"] == 2:
        s += 3

    if d["apnea_present"] == 1 or d["shock_present"] == 1:
        s += 3

    if d["heart_rate_bpm"] > 160:
        s += 2

    if d["respiratory_distress"] == 1:
        s += 2

    mnrs_list.append(s)

df["mnrs_score"] = mnrs_list

# %%
df["mnrs_score"].describe()
df.groupby("risk_level")["mnrs_score"].mean()
# Out:
# risk_level
# 0     3.811083
# 1    15.286252
# 2    30.697842
# Name: mnrs_score, dtype: float64

# %%
import math

labels = []

for i, row in df.iterrows():

    # sigmoid around MNRS = 12
    base = 1 / (1 + math.exp(-(row["mnrs_score"] - 12) / 4))

    if row["hss_score"] >= 4:
        base += 0.10
    if row["shock_present"] == 1:
        base += 0.10

    prob = min(max(base, 0.05), 0.95)

    label = 1 if random.random() < prob else 0
    labels.append(label)

df["sepsis_label"] = labels

# %%
df.groupby("mnrs_score")["sepsis_label"].mean().head(10)
df.groupby("mnrs_score")["sepsis_label"].mean().tail(10)

df.groupby("risk_level")["sepsis_label"].mean()
# Out:
# risk_level
# 0    0.125945
# 1    0.657250
# 2    0.949640
# Name: sepsis_label, dtype: float64

# %%
df_final = df.drop(columns=["risk_level"])

# %%
# !pip install synthcity
from synthcity.plugins import Plugins
# Out:
# Requirement already satisfied: synthcity in /usr/local/lib/python3.12/dist-packages (0.2.12)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from synthcity) (8.7.1)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.12/dist-packages (from synthcity) (2.2.2)
# Requirement already satisfied: torch<2.3,>=2.1 in /usr/local/lib/python3.12/dist-packages (from synthcity) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.2 in /usr/local/lib/python3.12/dist-packages (from synthcity) (1.6.1)
# Requirement already satisfied: nflows>=0.14 in /usr/local/lib/python3.12/dist-packages (from synthcity) (0.14)
# Requirement already satisfied: numpy<2.0,>=1.20 in /usr/local/lib/python3.12/dist-packages (from synthcity) (1.26.4)
# Requirement already satisfied: lifelines<0.30.0,>=0.29.0 in /usr/local/lib/python3.12/dist-packages (from synthcity) (0.29.0)
# Requirement already satisfied: opacus>=1.3 in /usr/local/lib/python3.12/dist-packages (from synthcity) (1.4.0)
# Requirement already satisfied: networkx<3.0,>2.0 in /usr/local/lib/python3.12/dist-packages (from synthcity) (2.8.8)
# Requirement already satisfied: decaf-synthetic-data>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from synthcity) (0.1.7)
# Requirement already satisfied: optuna>=3.1 in /usr/local/lib/python3.12/dist-packages (from synthcity) (4.7.0)
# Requirement already satisfied: shap in /usr/local/lib/python3.12/dist-packages (from synthcity) (0.49.1)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.12/dist-packages (from synthcity) (9.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from synthcity) (4.67.1)
# Requirement already satisfied: loguru in /usr/local/lib/python3.12/dist-packages (from synthcity) (0.7.3)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from synthcity) (2.12.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from synthcity) (3.1.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from synthcity) (1.16.3)
# Requirement already satisfied: xgboost<3.0.0 in /usr/local/lib/python3.12/dist-packages (from synthcity) (2.1.4)
# Requirement already satisfied: geomloss in /usr/local/lib/python3.12/dist-packages (from synthcity) (0.2.6)
# Requirement already satisfied: pgmpy<1.0 in /usr/local/lib/python3.12/dist-packages (from synthcity) (0.1.26)
# Requirement already satisfied: redis in /usr/local/lib/python3.12/dist-packages (from synthcity) (7.1.0)
# Requirement already satisfied: pycox in /usr/local/lib/python3.12/dist-packages (from synthcity) (0.3.0)
# Requirement already satisfied: xgbse>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from synthcity) (0.3.3)
# Requirement already satisfied: pykeops in /usr/local/lib/python3.12/dist-packages (from synthcity) (2.3)
# Requirement already satisfied: fflows in /usr/local/lib/python3.12/dist-packages (from synthcity) (0.0.3)
# Requirement already satisfied: monai in /usr/local/lib/python3.12/dist-packages (from synthcity) (1.4.0)
# Requirement already satisfied: tsai in /usr/local/lib/python3.12/dist-packages (from synthcity) (0.4.0)
# Requirement already satisfied: be-great>=0.0.5 in /usr/local/lib/python3.12/dist-packages (from synthcity) (0.0.9)
# Requirement already satisfied: arfpy in /usr/local/lib/python3.12/dist-packages (from synthcity) (0.1.1)
# Requirement already satisfied: fastcore<1.8 in /usr/local/lib/python3.12/dist-packages (from synthcity) (1.7.29)
# Requirement already satisfied: fastai<2.8 in /usr/local/lib/python3.12/dist-packages (from synthcity) (2.7.19)
# Requirement already satisfied: datasets>=2.5.2 in /usr/local/lib/python3.12/dist-packages (from be-great>=0.0.5->synthcity) (4.0.0)
# Requirement already satisfied: transformers>=4.22.1 in /usr/local/lib/python3.12/dist-packages (from be-great>=0.0.5->synthcity) (4.57.6)
# Requirement already satisfied: accelerate>=0.20.1 in /usr/local/lib/python3.12/dist-packages (from be-great>=0.0.5->synthcity) (1.12.0)
# Requirement already satisfied: pytorch-lightning>=2.4 in /usr/local/lib/python3.12/dist-packages (from decaf-synthetic-data>=0.1.6->synthcity) (2.6.0)
# Requirement already satisfied: torchtext>=0.10 in /usr/local/lib/python3.12/dist-packages (from decaf-synthetic-data>=0.1.6->synthcity) (0.17.2)
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (from fastai<2.8->synthcity) (24.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from fastai<2.8->synthcity) (25.0)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /usr/local/lib/python3.12/dist-packages (from fastai<2.8->synthcity) (0.0.7)
# Requirement already satisfied: torchvision>=0.11 in /usr/local/lib/python3.12/dist-packages (from fastai<2.8->synthcity) (0.17.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from fastai<2.8->synthcity) (3.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from fastai<2.8->synthcity) (2.32.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from fastai<2.8->synthcity) (6.0.3)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.12/dist-packages (from fastai<2.8->synthcity) (1.0.5)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from fastai<2.8->synthcity) (11.3.0)
# Requirement already satisfied: spacy<4 in /usr/local/lib/python3.12/dist-packages (from fastai<2.8->synthcity) (3.8.11)
# Requirement already satisfied: autograd>=1.5 in /usr/local/lib/python3.12/dist-packages (from lifelines<0.30.0,>=0.29.0->synthcity) (1.8.0)
# Requirement already satisfied: autograd-gamma>=0.3 in /usr/local/lib/python3.12/dist-packages (from lifelines<0.30.0,>=0.29.0->synthcity) (0.5.0)
# Requirement already satisfied: formulaic>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from lifelines<0.30.0,>=0.29.0->synthcity) (1.2.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from nflows>=0.14->synthcity) (2.19.0)
# Requirement already satisfied: opt-einsum>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from opacus>=1.3->synthcity) (3.4.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.1->synthcity) (1.18.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna>=3.1->synthcity) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.1->synthcity) (2.0.45)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->synthcity) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->synthcity) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->synthcity) (2025.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from pgmpy<1.0->synthcity) (3.3.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (from pgmpy<1.0->synthcity) (0.14.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from pgmpy<1.0->synthcity) (1.5.3)
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.12/dist-packages (from pgmpy<1.0->synthcity) (0.8.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->synthcity) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->synthcity) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->synthcity) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->synthcity) (0.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2->synthcity) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<2.3,>=2.1->synthcity) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch<2.3,>=2.1->synthcity) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<2.3,>=2.1->synthcity) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<2.3,>=2.1->synthcity) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<2.3,>=2.1->synthcity) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<2.3,>=2.1->synthcity) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<2.3,>=2.1->synthcity) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.12/dist-packages (from torch<2.3,>=2.1->synthcity) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.3,>=2.1->synthcity) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from torch<2.3,>=2.1->synthcity) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from torch<2.3,>=2.1->synthcity) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from torch<2.3,>=2.1->synthcity) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from torch<2.3,>=2.1->synthcity) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.3,>=2.1->synthcity) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<2.3,>=2.1->synthcity) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<2.3,>=2.1->synthcity) (12.9.86)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->synthcity) (3.23.0)
# Requirement already satisfied: torchtuples>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from pycox->synthcity) (0.2.2)
# Requirement already satisfied: feather-format>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pycox->synthcity) (0.4.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from pycox->synthcity) (3.15.1)
# Requirement already satisfied: numba>=0.44 in /usr/local/lib/python3.12/dist-packages (from pycox->synthcity) (0.60.0)
# Requirement already satisfied: py7zr>=0.11.3 in /usr/local/lib/python3.12/dist-packages (from pycox->synthcity) (1.1.2)
# Requirement already satisfied: pybind11 in /usr/local/lib/python3.12/dist-packages (from pykeops->synthcity) (3.0.1)
# Requirement already satisfied: keopscore==2.3 in /usr/local/lib/python3.12/dist-packages (from pykeops->synthcity) (2.3)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap->synthcity) (0.0.8)
# Requirement already satisfied: pyts>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from tsai->synthcity) (0.13.0)
# Requirement already satisfied: imbalanced-learn>=0.12.4 in /usr/local/lib/python3.12/dist-packages (from tsai->synthcity) (0.14.1)
# Requirement already satisfied: psutil>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from tsai->synthcity) (7.2.2)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.20.1->be-great>=0.0.5->synthcity) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.20.1->be-great>=0.0.5->synthcity) (0.7.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.1->synthcity) (1.3.10)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.5.2->be-great>=0.0.5->synthcity) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.5.2->be-great>=0.0.5->synthcity) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.5.2->be-great>=0.0.5->synthcity) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.5.2->be-great>=0.0.5->synthcity) (0.70.16)
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines<0.30.0,>=0.29.0->synthcity) (1.3.0)
# Requirement already satisfied: narwhals>=1.17 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines<0.30.0,>=0.29.0->synthcity) (2.15.0)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines<0.30.0,>=0.29.0->synthcity) (2.0.1)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn>=0.12.4->tsai->synthcity) (0.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->fastai<2.8->synthcity) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->fastai<2.8->synthcity) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->fastai<2.8->synthcity) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->fastai<2.8->synthcity) (1.4.9)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.44->pycox->synthcity) (0.43.0)
# Requirement already satisfied: texttable in /usr/local/lib/python3.12/dist-packages (from py7zr>=0.11.3->pycox->synthcity) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.20.0 in /usr/local/lib/python3.12/dist-packages (from py7zr>=0.11.3->pycox->synthcity) (3.23.0)
# Requirement already satisfied: brotli>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from py7zr>=0.11.3->pycox->synthcity) (1.2.0)
# Requirement already satisfied: backports.zstd>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from py7zr>=0.11.3->pycox->synthcity) (1.3.0)
# Requirement already satisfied: pyppmd>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from py7zr>=0.11.3->pycox->synthcity) (1.3.1)
# Requirement already satisfied: pybcj>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from py7zr>=0.11.3->pycox->synthcity) (1.0.7)
# Requirement already satisfied: multivolumefile>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from py7zr>=0.11.3->pycox->synthcity) (0.2.3)
# Requirement already satisfied: inflate64>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from py7zr>=0.11.3->pycox->synthcity) (1.0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.1->synthcity) (1.17.0)
# Requirement already satisfied: torchmetrics>0.7.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning>=2.4->decaf-synthetic-data>=0.1.6->synthcity) (1.8.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning>=2.4->decaf-synthetic-data>=0.1.6->synthcity) (0.15.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->fastai<2.8->synthcity) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->fastai<2.8->synthcity) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->fastai<2.8->synthcity) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->fastai<2.8->synthcity) (2026.1.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy<4->fastai<2.8->synthcity) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4->fastai<2.8->synthcity) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4->fastai<2.8->synthcity) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy<4->fastai<2.8->synthcity) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy<4->fastai<2.8->synthcity) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy<4->fastai<2.8->synthcity) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy<4->fastai<2.8->synthcity) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy<4->fastai<2.8->synthcity) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy<4->fastai<2.8->synthcity) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from spacy<4->fastai<2.8->synthcity) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4->fastai<2.8->synthcity) (0.21.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy<4->fastai<2.8->synthcity) (75.2.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.1->synthcity) (3.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.22.1->be-great>=0.0.5->synthcity) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.22.1->be-great>=0.0.5->synthcity) (0.22.2)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.12/dist-packages (from google-generativeai->pgmpy<1.0->synthcity) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from google-generativeai->pgmpy<1.0->synthcity) (2.29.0)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from google-generativeai->pgmpy<1.0->synthcity) (2.188.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-generativeai->pgmpy<1.0->synthcity) (2.43.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from google-generativeai->pgmpy<1.0->synthcity) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai->pgmpy<1.0->synthcity) (1.27.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<2.3,>=2.1->synthcity) (3.0.3)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels->pgmpy<1.0->synthcity) (1.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch<2.3,>=2.1->synthcity) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->nflows>=0.14->synthcity) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->nflows>=0.14->synthcity) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->nflows>=0.14->synthcity) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->nflows>=0.14->synthcity) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->nflows>=0.14->synthcity) (3.1.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->be-great>=0.0.5->synthcity) (3.13.3)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai->pgmpy<1.0->synthcity) (1.72.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai->pgmpy<1.0->synthcity) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai->pgmpy<1.0->synthcity) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai->pgmpy<1.0->synthcity) (4.9.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate>=0.20.1->be-great>=0.0.5->synthcity) (1.2.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy<4->fastai<2.8->synthcity) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy<4->fastai<2.8->synthcity) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim<1.0.0,>=0.3.0->spacy<4->fastai<2.8->synthcity) (8.3.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy<4->fastai<2.8->synthcity) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy<4->fastai<2.8->synthcity) (7.5.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai->pgmpy<1.0->synthcity) (0.31.1)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai->pgmpy<1.0->synthcity) (0.3.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai->pgmpy<1.0->synthcity) (4.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->be-great>=0.0.5->synthcity) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->be-great>=0.0.5->synthcity) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->be-great>=0.0.5->synthcity) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->be-great>=0.0.5->synthcity) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->be-great>=0.0.5->synthcity) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->be-great>=0.0.5->synthcity) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->be-great>=0.0.5->synthcity) (1.22.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai->pgmpy<1.0->synthcity) (1.71.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai->pgmpy<1.0->synthcity) (0.6.2)
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# [KeOps] Warning : CUDA libraries not found or could not be loaded; Switching to CPU only.

# %%
# Initialize CTGAN plugin
plugin = Plugins().get(
    "ctgan",
    n_iter=300,          # training iterations
    batch_size=512,
    lr=2e-4,
    generator_n_layers_hidden=2,
    discriminator_n_layers_hidden=2
)

# Define the target column
target_column = "sepsis_label"

# Fit on seed dataset
plugin.fit(
    df_final,
    target_column=target_column
)
# Out:
# [2026-01-29T18:32:04.974232+0000][38752][CRITICAL] load failed: module 'synthcity.plugins.generic.plugin_great' has no attribute 'plugin'
# [2026-01-29T18:32:04.975781+0000][38752][CRITICAL] load failed: module 'synthcity.plugins.generic.plugin_great' has no attribute 'plugin'
# [2026-01-29T18:32:04.976877+0000][38752][CRITICAL] module plugin_great load failed
# [2026-01-29T18:32:04.978870+0000][38752][CRITICAL] module disabled: /usr/local/lib/python3.12/dist-packages/synthcity/plugins/generic/plugin_goggle.py
# 100%|██████████| 300/300 [08:14<00:00,  1.65s/it]

# %%
N_SYNTH = 20000

synthetic_df = plugin.generate(N_SYNTH)

synthetic_df.dataframe().head()
# Out:
#    prom_present  chorioamnionitis  foul_smelling_liquor  prolonged_labor  \
# 0             1                 0                     0                0
# 1             0                 1                     1                0
# 2             0                 0                     0                0
# 3             1                 0                     0                1
# 4             1                 0                     0                0
#
#    unbooked_pregnancy  maternal_uti_sti  meconium_stained_liquor  cotwin_iud  \
# 0                   0                 0                        1           0
# 1                   1                 1                        1           0
# 2                   1                 0                        0           0
# 3                   0                 0                        0           0
# 4                   0                 0                        0           0
#
#    pv_examinations_count  prom_duration_hours  ...  apgar5_grimace  \
# 0                      2             6.236439  ...               2
# 1                      3             0.040409  ...               0
# 2                      2             0.000000  ...               1
# 3                      2             6.103503  ...               2
# 4                      1             5.560599  ...               2
#
#    apgar5_activity  apgar5_respiration  apgar5_total  \
# 0                2                   2             9
# 1                2                   1             2
# 2                2                   2             9
# 3                2                   1             9
# 4                1                   2            10
#
#    gestational_age_category  birth_weight_category  resuscitation_required  \
# 0                       ≥37                  ≥2500                       0
# 1                     34–36              1500–2499                       0
# 2                     34–36                  ≥2500                       0
# 3                       ≥37                  ≥2500                       0
# 4                       ≥37                  ≥2500                       0
#
#    neonatal_sex  mnrs_score  sepsis_label
# 0        female           7             0
# 1          male          33             1
# 2          male           7             0
# 3        female           8             1
# 4          male           3             0
#
# [5 rows x 44 columns]

# %%
synthetic_df = synthetic_df.dataframe() # Convert to pandas DataFrame

# Shape check
synthetic_df.shape

# Label distribution
synthetic_df["sepsis_label"].mean()

# MNRS vs sepsis sanity
synthetic_df.groupby("mnrs_score")["sepsis_label"].mean().head()
synthetic_df.groupby("mnrs_score")["sepsis_label"].mean().tail()

# Risk proxies sanity
synthetic_df["temperature_celsius"].describe()
synthetic_df["hss_score"].describe()
# Out:
# count    20000.000000
# mean         1.302000
# std          1.661124
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max          7.000000
# Name: hss_score, dtype: float64

# %%
synthetic_df.to_csv(
    "septoctor_training_dataset_20k.csv",
    index=False
)

print("Saved final dataset:", synthetic_df.shape)
# Out:
# Saved final dataset: (20000, 44)
